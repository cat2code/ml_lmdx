# %% [markdown]
# ## Hans Alin gjorde fina plots - 2D plots ECal RecHits

# %% [markdown]
# Om man vill navigera sig i events.root-filer med ROOT-programmet (tips från Lene-Kristian)
#
# denv rootbrowse runs/it_pileup/events.root

# %% [markdown]
# ## Inspection + make lists

# %% [markdown]
# Importera och välj events-fil
#
# Inspektera filen och se vilka unika keys som finns i den

# %%
import uproot
import matplotlib.pyplot as plt
import awkward as ak

events_path = "../data/overlay_main10_pileup20_00/events.root"
figures_path = "../figures/notebooks/"

file = uproot.open(events_path)
tree = file["LDMX_Events"]

f_inspect = uproot.open(events_path)

keys = [k.split(";")[0] for k in f_inspect.keys()]  # strip ROOT cycle suffix ";1"
keys = sorted(set(keys))

print(f"Found {len(keys)} unique objects in {events_path}\n")
for k in keys:
    print(k)

print("\nBRANCHES (no leaves):")
branches_no_leaves = sorted({b.split("/")[0] for b in tree.keys()})
for b in branches_no_leaves:
    print(b)

print("\nBRANCHES:")
for b in tree.keys():
    print(b)
# Out:
# Found 2 unique objects in ../data/overlay_main10_pileup20_00/events.root
#
# LDMX_Events
# LDMX_Run
#
# BRANCHES (no leaves):
# DigiRecoilSimHits_overlay
# DigiTaggerSimHits_overlay
# EcalClustersCast_overlay
# EcalClusters_overlay
# EcalDigis_overlay
# EcalMipInfo_overlay
# EcalPnetVeto_overlay
# EcalRecHitsNoPileup_overlay
# EcalRecHits_overlay
# EcalScoringPlaneHitsOverlay_overlay
# EcalScoringPlaneHits_ecal_pn
# EcalSimHitsOverlay_overlay
# EcalSimHits_ecal_pn
# EcalTrajectoryInfo_overlay
# EcalVeto_overlay
# EventHeader
# GSFRecoilTracks_overlay
# GSFTaggerTracks_overlay
# HcalDigis_overlay
# HcalRecHits_overlay
# HcalSimHitsOverlay_overlay
# HcalSimHits_ecal_pn
# HcalTotalEnergy_overlay
# HcalVeto_overlay
# PFCandidates_overlay
# PFHcalClusters_overlay
# PFTracks_overlay
# PFTruthEcal_overlay
# PFTruthHcal_overlay
# PFTruthTarget_overlay
# PFTruth_overlay
# RecoilRecoSeeds_overlay
# RecoilSimHitsOverlay_overlay
# RecoilSimHits_ecal_pn
# RecoilTracksClean_overlay
# RecoilTracks_overlay
# RecoilTruthSeeds_overlay
# RecoilTruthTracks_overlay
# SimParticles_ecal_pn
# TaggerRecoSeeds_overlay
# TaggerSimHitsOverlay_overlay
# TaggerSimHits_ecal_pn
# TaggerTracksClean_overlay
# TaggerTracks_overlay
# TaggerTruthSeeds_overlay
# TaggerTruthTracks_overlay
# TargetScoringPlaneHits_ecal_pn
# TargetSimHitsOverlay_overlay
# TargetSimHits_ecal_pn
# TrackerVeto_overlay
# TriggerPad1Clusters_overlay
# TriggerPad1SimHitsOverlay_overlay
# TriggerPad1SimHits_ecal_pn
# TriggerPad2Clusters_overlay
# TriggerPad2SimHitsOverlay_overlay
# TriggerPad2SimHits_ecal_pn
# TriggerPad3Clusters_overlay
# TriggerPad3SimHitsOverlay_overlay
# TriggerPad3SimHits_ecal_pn
# TriggerPadTracksX_overlay
# TriggerPadTracksY_overlay
# TriggerPadTracks_overlay
# Trigger_overlay
# beamElectrons_overlay
# trigScintDigisPad1_overlay
# trigScintDigisPad2_overlay
# trigScintDigisPad3_overlay
#
# BRANCHES:
# EventHeader
# EventHeader/event_number_
# EventHeader/run_
# EventHeader/timestamp_
# EventHeader/timestamp_/timestamp_.fSec
# EventHeader/timestamp_/timestamp_.fNanoSec
# EventHeader/weight_
# EventHeader/is_real_data_
# EventHeader/int_parameters_
# EventHeader/int_parameters_/int_parameters_.first
# EventHeader/int_parameters_/int_parameters_.second
# EventHeader/float_parameters_
# EventHeader/float_parameters_/float_parameters_.first
# EventHeader/float_parameters_/float_parameters_.second
# EventHeader/string_parameters_
# EventHeader/string_parameters_/string_parameters_.first
# EventHeader/string_parameters_/string_parameters_.second
# SimParticles_ecal_pn
# SimParticles_ecal_pn/SimParticles_ecal_pn.first
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.energy_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.pdg_id_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.gen_status_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.time_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.vtx_x_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.vtx_y_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.vtx_z_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.end_x_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.end_y_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.end_z_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.px_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.py_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.pz_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.end_px_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.end_py_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.end_pz_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.mass_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.charge_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.daughters_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.parents_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.process_type_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.vertex_volume_
# SimParticles_ecal_pn/SimParticles_ecal_pn.second.interaction_material_
# TaggerSimHits_ecal_pn
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.id_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.layer_id_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.module_id_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.edep_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.time_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.px_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.py_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.pz_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.energy_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.x_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.y_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.z_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.path_length_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.track_id_
# TaggerSimHits_ecal_pn/TaggerSimHits_ecal_pn.pdg_id_
# RecoilSimHits_ecal_pn
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.id_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.layer_id_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.module_id_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.edep_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.time_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.px_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.py_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.pz_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.energy_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.x_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.y_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.z_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.path_length_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.track_id_
# RecoilSimHits_ecal_pn/RecoilSimHits_ecal_pn.pdg_id_
# HcalSimHits_ecal_pn
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.id_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.edep_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.x_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.y_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.z_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.time_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.track_id_contribs_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.incident_id_contribs_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.pdg_code_contribs_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.edep_contribs_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.time_contribs_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.origin_contribs_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.n_contribs_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.path_length_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.pre_step_x_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.pre_step_y_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.pre_step_z_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.pre_step_time_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.post_step_x_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.post_step_y_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.post_step_z_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.post_step_time_
# HcalSimHits_ecal_pn/HcalSimHits_ecal_pn.velocity_
# EcalSimHits_ecal_pn
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.id_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.edep_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.x_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.y_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.z_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.time_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.track_id_contribs_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.incident_id_contribs_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.pdg_code_contribs_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.edep_contribs_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.time_contribs_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.origin_contribs_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.n_contribs_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.path_length_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.pre_step_x_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.pre_step_y_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.pre_step_z_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.pre_step_time_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.post_step_x_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.post_step_y_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.post_step_z_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.post_step_time_
# EcalSimHits_ecal_pn/EcalSimHits_ecal_pn.velocity_
# TargetSimHits_ecal_pn
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.id_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.edep_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.x_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.y_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.z_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.time_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.track_id_contribs_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.incident_id_contribs_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.pdg_code_contribs_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.edep_contribs_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.time_contribs_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.origin_contribs_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.n_contribs_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.path_length_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.pre_step_x_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.pre_step_y_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.pre_step_z_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.pre_step_time_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.post_step_x_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.post_step_y_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.post_step_z_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.post_step_time_
# TargetSimHits_ecal_pn/TargetSimHits_ecal_pn.velocity_
# TriggerPad1SimHits_ecal_pn
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.id_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.edep_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.x_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.y_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.z_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.time_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.track_id_contribs_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.incident_id_contribs_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.pdg_code_contribs_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.edep_contribs_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.time_contribs_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.origin_contribs_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.n_contribs_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.path_length_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.pre_step_x_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.pre_step_y_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.pre_step_z_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.pre_step_time_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.post_step_x_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.post_step_y_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.post_step_z_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.post_step_time_
# TriggerPad1SimHits_ecal_pn/TriggerPad1SimHits_ecal_pn.velocity_
# TriggerPad2SimHits_ecal_pn
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.id_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.edep_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.x_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.y_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.z_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.time_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.track_id_contribs_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.incident_id_contribs_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.pdg_code_contribs_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.edep_contribs_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.time_contribs_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.origin_contribs_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.n_contribs_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.path_length_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.pre_step_x_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.pre_step_y_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.pre_step_z_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.pre_step_time_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.post_step_x_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.post_step_y_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.post_step_z_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.post_step_time_
# TriggerPad2SimHits_ecal_pn/TriggerPad2SimHits_ecal_pn.velocity_
# TriggerPad3SimHits_ecal_pn
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.id_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.edep_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.x_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.y_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.z_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.time_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.track_id_contribs_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.incident_id_contribs_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.pdg_code_contribs_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.edep_contribs_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.time_contribs_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.origin_contribs_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.n_contribs_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.path_length_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.pre_step_x_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.pre_step_y_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.pre_step_z_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.pre_step_time_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.post_step_x_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.post_step_y_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.post_step_z_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.post_step_time_
# TriggerPad3SimHits_ecal_pn/TriggerPad3SimHits_ecal_pn.velocity_
# TargetScoringPlaneHits_ecal_pn
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.id_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.layer_id_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.module_id_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.edep_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.time_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.px_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.py_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.pz_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.energy_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.x_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.y_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.z_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.path_length_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.track_id_
# TargetScoringPlaneHits_ecal_pn/TargetScoringPlaneHits_ecal_pn.pdg_id_
# EcalScoringPlaneHits_ecal_pn
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.id_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.layer_id_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.module_id_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.edep_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.time_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.px_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.py_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.pz_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.energy_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.x_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.y_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.z_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.path_length_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.track_id_
# EcalScoringPlaneHits_ecal_pn/EcalScoringPlaneHits_ecal_pn.pdg_id_
# EcalSimHitsOverlay_overlay
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.id_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.edep_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.x_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.y_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.z_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.time_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.track_id_contribs_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.incident_id_contribs_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.pdg_code_contribs_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.edep_contribs_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.time_contribs_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.origin_contribs_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.n_contribs_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.path_length_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.pre_step_x_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.pre_step_y_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.pre_step_z_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.pre_step_time_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.post_step_x_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.post_step_y_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.post_step_z_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.post_step_time_
# EcalSimHitsOverlay_overlay/EcalSimHitsOverlay_overlay.velocity_
# HcalSimHitsOverlay_overlay
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.id_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.edep_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.x_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.y_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.z_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.time_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.track_id_contribs_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.incident_id_contribs_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.pdg_code_contribs_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.edep_contribs_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.time_contribs_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.origin_contribs_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.n_contribs_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.path_length_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.pre_step_x_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.pre_step_y_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.pre_step_z_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.pre_step_time_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.post_step_x_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.post_step_y_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.post_step_z_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.post_step_time_
# HcalSimHitsOverlay_overlay/HcalSimHitsOverlay_overlay.velocity_
# TargetSimHitsOverlay_overlay
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.id_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.edep_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.x_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.y_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.z_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.time_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.track_id_contribs_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.incident_id_contribs_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.pdg_code_contribs_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.edep_contribs_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.time_contribs_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.origin_contribs_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.n_contribs_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.path_length_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.pre_step_x_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.pre_step_y_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.pre_step_z_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.pre_step_time_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.post_step_x_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.post_step_y_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.post_step_z_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.post_step_time_
# TargetSimHitsOverlay_overlay/TargetSimHitsOverlay_overlay.velocity_
# TriggerPad1SimHitsOverlay_overlay
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.id_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.edep_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.x_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.y_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.z_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.time_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.track_id_contribs_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.incident_id_contribs_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.pdg_code_contribs_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.edep_contribs_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.time_contribs_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.origin_contribs_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.n_contribs_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.path_length_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.pre_step_x_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.pre_step_y_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.pre_step_z_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.pre_step_time_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.post_step_x_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.post_step_y_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.post_step_z_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.post_step_time_
# TriggerPad1SimHitsOverlay_overlay/TriggerPad1SimHitsOverlay_overlay.velocity_
# TriggerPad2SimHitsOverlay_overlay
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.id_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.edep_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.x_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.y_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.z_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.time_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.track_id_contribs_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.incident_id_contribs_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.pdg_code_contribs_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.edep_contribs_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.time_contribs_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.origin_contribs_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.n_contribs_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.path_length_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.pre_step_x_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.pre_step_y_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.pre_step_z_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.pre_step_time_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.post_step_x_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.post_step_y_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.post_step_z_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.post_step_time_
# TriggerPad2SimHitsOverlay_overlay/TriggerPad2SimHitsOverlay_overlay.velocity_
# TriggerPad3SimHitsOverlay_overlay
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.id_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.edep_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.x_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.y_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.z_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.time_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.track_id_contribs_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.incident_id_contribs_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.pdg_code_contribs_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.edep_contribs_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.time_contribs_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.origin_contribs_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.n_contribs_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.path_length_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.pre_step_x_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.pre_step_y_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.pre_step_z_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.pre_step_time_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.post_step_x_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.post_step_y_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.post_step_z_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.post_step_time_
# TriggerPad3SimHitsOverlay_overlay/TriggerPad3SimHitsOverlay_overlay.velocity_
# EcalScoringPlaneHitsOverlay_overlay
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.id_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.layer_id_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.module_id_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.edep_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.time_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.px_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.py_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.pz_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.energy_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.x_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.y_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.z_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.path_length_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.track_id_
# EcalScoringPlaneHitsOverlay_overlay/EcalScoringPlaneHitsOverlay_overlay.pdg_id_
# RecoilSimHitsOverlay_overlay
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.id_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.layer_id_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.module_id_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.edep_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.time_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.px_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.py_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.pz_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.energy_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.x_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.y_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.z_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.path_length_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.track_id_
# RecoilSimHitsOverlay_overlay/RecoilSimHitsOverlay_overlay.pdg_id_
# TaggerSimHitsOverlay_overlay
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.id_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.layer_id_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.module_id_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.edep_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.time_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.px_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.py_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.pz_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.energy_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.x_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.y_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.z_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.path_length_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.track_id_
# TaggerSimHitsOverlay_overlay/TaggerSimHitsOverlay_overlay.pdg_id_
# DigiTaggerSimHits_overlay
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.meas_x_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.meas_y_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.meas_z_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.meas_t_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.meas_u_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.meas_v_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.layer_id_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.layer_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.edep_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.cov_uu_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.cov_vv_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.id_
# DigiTaggerSimHits_overlay/DigiTaggerSimHits_overlay.track_ids_
# DigiRecoilSimHits_overlay
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.meas_x_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.meas_y_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.meas_z_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.meas_t_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.meas_u_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.meas_v_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.layer_id_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.layer_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.edep_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.cov_uu_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.cov_vv_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.id_
# DigiRecoilSimHits_overlay/DigiRecoilSimHits_overlay.track_ids_
# beamElectrons_overlay
# beamElectrons_overlay/beamElectrons_overlay.n_hits_
# beamElectrons_overlay/beamElectrons_overlay.n_outliers_
# beamElectrons_overlay/beamElectrons_overlay.ndf_
# beamElectrons_overlay/beamElectrons_overlay.n_shared_hits_
# beamElectrons_overlay/beamElectrons_overlay.n_holes_
# beamElectrons_overlay/beamElectrons_overlay.chi2_
# beamElectrons_overlay/beamElectrons_overlay.perigee_pars_
# beamElectrons_overlay/beamElectrons_overlay.perigee_cov_
# beamElectrons_overlay/beamElectrons_overlay.perigee_
# beamElectrons_overlay/beamElectrons_overlay.momentum_
# beamElectrons_overlay/beamElectrons_overlay.position_
# beamElectrons_overlay/beamElectrons_overlay.meas_idxs_
# beamElectrons_overlay/beamElectrons_overlay.outlier_idxs_
# beamElectrons_overlay/beamElectrons_overlay.hole_idxs_
# beamElectrons_overlay/beamElectrons_overlay.shared_idxs_
# beamElectrons_overlay/beamElectrons_overlay.dedx_measurements_
# beamElectrons_overlay/beamElectrons_overlay.track_id_
# beamElectrons_overlay/beamElectrons_overlay.truth_prob_
# beamElectrons_overlay/beamElectrons_overlay.pdg_id_
# beamElectrons_overlay/beamElectrons_overlay.track_states_
# TaggerTruthTracks_overlay
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.n_hits_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.n_outliers_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.ndf_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.n_shared_hits_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.n_holes_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.chi2_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.perigee_pars_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.perigee_cov_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.perigee_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.momentum_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.position_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.meas_idxs_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.outlier_idxs_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.hole_idxs_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.shared_idxs_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.dedx_measurements_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.track_id_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.truth_prob_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.pdg_id_
# TaggerTruthTracks_overlay/TaggerTruthTracks_overlay.track_states_
# RecoilTruthTracks_overlay
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.n_hits_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.n_outliers_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.ndf_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.n_shared_hits_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.n_holes_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.chi2_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.perigee_pars_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.perigee_cov_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.perigee_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.momentum_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.position_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.meas_idxs_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.outlier_idxs_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.hole_idxs_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.shared_idxs_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.dedx_measurements_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.track_id_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.truth_prob_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.pdg_id_
# RecoilTruthTracks_overlay/RecoilTruthTracks_overlay.track_states_
# TaggerTruthSeeds_overlay
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.n_hits_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.n_outliers_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.ndf_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.n_shared_hits_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.n_holes_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.chi2_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.perigee_pars_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.perigee_cov_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.perigee_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.momentum_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.position_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.meas_idxs_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.outlier_idxs_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.hole_idxs_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.shared_idxs_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.dedx_measurements_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.track_id_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.truth_prob_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.pdg_id_
# TaggerTruthSeeds_overlay/TaggerTruthSeeds_overlay.track_states_
# RecoilTruthSeeds_overlay
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.n_hits_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.n_outliers_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.ndf_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.n_shared_hits_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.n_holes_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.chi2_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.perigee_pars_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.perigee_cov_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.perigee_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.momentum_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.position_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.meas_idxs_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.outlier_idxs_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.hole_idxs_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.shared_idxs_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.dedx_measurements_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.track_id_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.truth_prob_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.pdg_id_
# RecoilTruthSeeds_overlay/RecoilTruthSeeds_overlay.track_states_
# TaggerRecoSeeds_overlay
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.n_hits_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.n_outliers_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.ndf_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.n_shared_hits_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.n_holes_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.chi2_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.perigee_pars_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.perigee_cov_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.perigee_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.momentum_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.position_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.meas_idxs_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.outlier_idxs_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.hole_idxs_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.shared_idxs_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.dedx_measurements_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.track_id_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.truth_prob_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.pdg_id_
# TaggerRecoSeeds_overlay/TaggerRecoSeeds_overlay.track_states_
# RecoilRecoSeeds_overlay
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.n_hits_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.n_outliers_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.ndf_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.n_shared_hits_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.n_holes_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.chi2_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.perigee_pars_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.perigee_cov_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.perigee_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.momentum_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.position_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.meas_idxs_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.outlier_idxs_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.hole_idxs_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.shared_idxs_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.dedx_measurements_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.track_id_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.truth_prob_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.pdg_id_
# RecoilRecoSeeds_overlay/RecoilRecoSeeds_overlay.track_states_
# TaggerTracks_overlay
# TaggerTracks_overlay/TaggerTracks_overlay.n_hits_
# TaggerTracks_overlay/TaggerTracks_overlay.n_outliers_
# TaggerTracks_overlay/TaggerTracks_overlay.ndf_
# TaggerTracks_overlay/TaggerTracks_overlay.n_shared_hits_
# TaggerTracks_overlay/TaggerTracks_overlay.n_holes_
# TaggerTracks_overlay/TaggerTracks_overlay.chi2_
# TaggerTracks_overlay/TaggerTracks_overlay.perigee_pars_
# TaggerTracks_overlay/TaggerTracks_overlay.perigee_cov_
# TaggerTracks_overlay/TaggerTracks_overlay.perigee_
# TaggerTracks_overlay/TaggerTracks_overlay.momentum_
# TaggerTracks_overlay/TaggerTracks_overlay.position_
# TaggerTracks_overlay/TaggerTracks_overlay.meas_idxs_
# TaggerTracks_overlay/TaggerTracks_overlay.outlier_idxs_
# TaggerTracks_overlay/TaggerTracks_overlay.hole_idxs_
# TaggerTracks_overlay/TaggerTracks_overlay.shared_idxs_
# TaggerTracks_overlay/TaggerTracks_overlay.dedx_measurements_
# TaggerTracks_overlay/TaggerTracks_overlay.track_id_
# TaggerTracks_overlay/TaggerTracks_overlay.truth_prob_
# TaggerTracks_overlay/TaggerTracks_overlay.pdg_id_
# TaggerTracks_overlay/TaggerTracks_overlay.track_states_
# RecoilTracks_overlay
# RecoilTracks_overlay/RecoilTracks_overlay.n_hits_
# RecoilTracks_overlay/RecoilTracks_overlay.n_outliers_
# RecoilTracks_overlay/RecoilTracks_overlay.ndf_
# RecoilTracks_overlay/RecoilTracks_overlay.n_shared_hits_
# RecoilTracks_overlay/RecoilTracks_overlay.n_holes_
# RecoilTracks_overlay/RecoilTracks_overlay.chi2_
# RecoilTracks_overlay/RecoilTracks_overlay.perigee_pars_
# RecoilTracks_overlay/RecoilTracks_overlay.perigee_cov_
# RecoilTracks_overlay/RecoilTracks_overlay.perigee_
# RecoilTracks_overlay/RecoilTracks_overlay.momentum_
# RecoilTracks_overlay/RecoilTracks_overlay.position_
# RecoilTracks_overlay/RecoilTracks_overlay.meas_idxs_
# RecoilTracks_overlay/RecoilTracks_overlay.outlier_idxs_
# RecoilTracks_overlay/RecoilTracks_overlay.hole_idxs_
# RecoilTracks_overlay/RecoilTracks_overlay.shared_idxs_
# RecoilTracks_overlay/RecoilTracks_overlay.dedx_measurements_
# RecoilTracks_overlay/RecoilTracks_overlay.track_id_
# RecoilTracks_overlay/RecoilTracks_overlay.truth_prob_
# RecoilTracks_overlay/RecoilTracks_overlay.pdg_id_
# RecoilTracks_overlay/RecoilTracks_overlay.track_states_
# TaggerTracksClean_overlay
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.n_hits_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.n_outliers_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.ndf_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.n_shared_hits_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.n_holes_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.chi2_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.perigee_pars_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.perigee_cov_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.perigee_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.momentum_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.position_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.meas_idxs_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.outlier_idxs_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.hole_idxs_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.shared_idxs_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.dedx_measurements_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.track_id_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.truth_prob_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.pdg_id_
# TaggerTracksClean_overlay/TaggerTracksClean_overlay.track_states_
# RecoilTracksClean_overlay
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.n_hits_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.n_outliers_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.ndf_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.n_shared_hits_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.n_holes_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.chi2_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.perigee_pars_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.perigee_cov_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.perigee_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.momentum_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.position_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.meas_idxs_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.outlier_idxs_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.hole_idxs_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.shared_idxs_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.dedx_measurements_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.track_id_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.truth_prob_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.pdg_id_
# RecoilTracksClean_overlay/RecoilTracksClean_overlay.track_states_
# GSFTaggerTracks_overlay
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.n_hits_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.n_outliers_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.ndf_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.n_shared_hits_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.n_holes_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.chi2_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.perigee_pars_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.perigee_cov_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.perigee_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.momentum_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.position_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.meas_idxs_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.outlier_idxs_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.hole_idxs_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.shared_idxs_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.dedx_measurements_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.track_id_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.truth_prob_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.pdg_id_
# GSFTaggerTracks_overlay/GSFTaggerTracks_overlay.track_states_
# GSFRecoilTracks_overlay
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.n_hits_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.n_outliers_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.ndf_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.n_shared_hits_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.n_holes_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.chi2_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.perigee_pars_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.perigee_cov_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.perigee_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.momentum_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.position_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.meas_idxs_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.outlier_idxs_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.hole_idxs_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.shared_idxs_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.dedx_measurements_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.track_id_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.truth_prob_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.pdg_id_
# GSFRecoilTracks_overlay/GSFRecoilTracks_overlay.track_states_
# TrackerVeto_overlay
# TrackerVeto_overlay/passes_veto_
# TrackerVeto_overlay/passes_tagger_veto_
# TrackerVeto_overlay/passes_recoil_veto_
# EcalDigis_overlay
# EcalDigis_overlay/channel_ids_
# EcalDigis_overlay/samples_
# EcalDigis_overlay/num_samples_per_digi_
# EcalDigis_overlay/sample_of_interest_
# EcalDigis_overlay/version_
# EcalRecHits_overlay
# EcalRecHits_overlay/EcalRecHits_overlay.id_
# EcalRecHits_overlay/EcalRecHits_overlay.amplitude_
# EcalRecHits_overlay/EcalRecHits_overlay.energy_
# EcalRecHits_overlay/EcalRecHits_overlay.time_
# EcalRecHits_overlay/EcalRecHits_overlay.xpos_
# EcalRecHits_overlay/EcalRecHits_overlay.ypos_
# EcalRecHits_overlay/EcalRecHits_overlay.zpos_
# EcalRecHits_overlay/EcalRecHits_overlay.is_noise_
# EcalTrajectoryInfo_overlay
# EcalTrajectoryInfo_overlay/ele_trajectory_
# EcalTrajectoryInfo_overlay/ele_trajectory_/ele_trajectory_.first
# EcalTrajectoryInfo_overlay/ele_trajectory_/ele_trajectory_.second
# EcalTrajectoryInfo_overlay/photon_trajectory_
# EcalTrajectoryInfo_overlay/photon_trajectory_/photon_trajectory_.first
# EcalTrajectoryInfo_overlay/photon_trajectory_/photon_trajectory_.second
# EcalTrajectoryInfo_overlay/tracking_hit_list_
# EcalVeto_overlay
# EcalVeto_overlay/passes_veto_
# EcalVeto_overlay/n_readout_hits_
# EcalVeto_overlay/deepest_layer_hit_
# EcalVeto_overlay/summed_det_
# EcalVeto_overlay/summed_tight_iso_
# ...
# TriggerPad1Clusters_overlay/TriggerPad1Clusters_overlay.time_
# TriggerPad2Clusters_overlay
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.hit_ids_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.energy_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.n_hits_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.pe_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.seed_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.centroid_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.centroid_x_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.centroid_y_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.centroid_z_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.beam_efrac_
# TriggerPad2Clusters_overlay/TriggerPad2Clusters_overlay.time_
# TriggerPad3Clusters_overlay
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.hit_ids_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.energy_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.n_hits_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.pe_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.seed_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.centroid_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.centroid_x_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.centroid_y_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.centroid_z_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.beam_efrac_
# TriggerPad3Clusters_overlay/TriggerPad3Clusters_overlay.time_
# TriggerPadTracks_overlay
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.centroid_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.centroid_x_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.centroid_y_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.centroid_z_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.residual_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.residual_x_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.residual_y_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.residual_z_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.n_clusters_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.constituents_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.beam_efrac_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.pe_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.x_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.y_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.sx_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.sy_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.px_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.py_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.pz_
# TriggerPadTracks_overlay/TriggerPadTracks_overlay.z_
# TriggerPadTracksY_overlay
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.centroid_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.centroid_x_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.centroid_y_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.centroid_z_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.residual_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.residual_x_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.residual_y_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.residual_z_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.n_clusters_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.constituents_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.beam_efrac_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.pe_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.x_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.y_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.sx_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.sy_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.px_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.py_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.pz_
# TriggerPadTracksY_overlay/TriggerPadTracksY_overlay.z_
# TriggerPadTracksX_overlay
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.centroid_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.centroid_x_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.centroid_y_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.centroid_z_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.residual_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.residual_x_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.residual_y_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.residual_z_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.n_clusters_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.constituents_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.beam_efrac_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.pe_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.x_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.y_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.sx_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.sy_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.px_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.py_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.pz_
# TriggerPadTracksX_overlay/TriggerPadTracksX_overlay.z_
# Trigger_overlay
# Trigger_overlay/name_
# Trigger_overlay/pass_
# Trigger_overlay/variables_
# EcalClusters_overlay
# EcalClusters_overlay/EcalClusters_overlay.hit_ids_
# EcalClusters_overlay/EcalClusters_overlay.energy_
# EcalClusters_overlay/EcalClusters_overlay.n_hits_
# EcalClusters_overlay/EcalClusters_overlay.centroid_x_
# EcalClusters_overlay/EcalClusters_overlay.centroid_y_
# EcalClusters_overlay/EcalClusters_overlay.centroid_z_
# EcalClusters_overlay/EcalClusters_overlay.layer_
# EcalClusters_overlay/EcalClusters_overlay.rms_x_
# EcalClusters_overlay/EcalClusters_overlay.rms_y_
# EcalClusters_overlay/EcalClusters_overlay.rms_z_
# EcalClusters_overlay/EcalClusters_overlay.dxdz_
# EcalClusters_overlay/EcalClusters_overlay.dydz_
# EcalClusters_overlay/EcalClusters_overlay.err_dxdz_
# EcalClusters_overlay/EcalClusters_overlay.err_dydz_
# EcalClusters_overlay/EcalClusters_overlay.hit_x_
# EcalClusters_overlay/EcalClusters_overlay.hit_y_
# EcalClusters_overlay/EcalClusters_overlay.hit_z_
# EcalClusters_overlay/EcalClusters_overlay.hit_e_
# EcalClusters_overlay/EcalClusters_overlay.first_layer_hit_ids_
# EcalClusters_overlay/EcalClusters_overlay.first_layer_centroid_x_
# EcalClusters_overlay/EcalClusters_overlay.first_layer_centroid_y_
# EcalClusters_overlay/EcalClusters_overlay.first_layer_centroid_z_
# PFTracks_overlay
# PFTracks_overlay/PFTracks_overlay.id_
# PFTracks_overlay/PFTracks_overlay.layer_id_
# PFTracks_overlay/PFTracks_overlay.module_id_
# PFTracks_overlay/PFTracks_overlay.edep_
# PFTracks_overlay/PFTracks_overlay.time_
# PFTracks_overlay/PFTracks_overlay.px_
# PFTracks_overlay/PFTracks_overlay.py_
# PFTracks_overlay/PFTracks_overlay.pz_
# PFTracks_overlay/PFTracks_overlay.energy_
# PFTracks_overlay/PFTracks_overlay.x_
# PFTracks_overlay/PFTracks_overlay.y_
# PFTracks_overlay/PFTracks_overlay.z_
# PFTracks_overlay/PFTracks_overlay.path_length_
# PFTracks_overlay/PFTracks_overlay.track_id_
# PFTracks_overlay/PFTracks_overlay.pdg_id_
# PFTruth_overlay
# PFTruth_overlay/PFTruth_overlay.first
# PFTruth_overlay/PFTruth_overlay.second.energy_
# PFTruth_overlay/PFTruth_overlay.second.pdg_id_
# PFTruth_overlay/PFTruth_overlay.second.gen_status_
# PFTruth_overlay/PFTruth_overlay.second.time_
# PFTruth_overlay/PFTruth_overlay.second.vtx_x_
# PFTruth_overlay/PFTruth_overlay.second.vtx_y_
# PFTruth_overlay/PFTruth_overlay.second.vtx_z_
# PFTruth_overlay/PFTruth_overlay.second.end_x_
# PFTruth_overlay/PFTruth_overlay.second.end_y_
# PFTruth_overlay/PFTruth_overlay.second.end_z_
# PFTruth_overlay/PFTruth_overlay.second.px_
# PFTruth_overlay/PFTruth_overlay.second.py_
# PFTruth_overlay/PFTruth_overlay.second.pz_
# PFTruth_overlay/PFTruth_overlay.second.end_px_
# PFTruth_overlay/PFTruth_overlay.second.end_py_
# PFTruth_overlay/PFTruth_overlay.second.end_pz_
# PFTruth_overlay/PFTruth_overlay.second.mass_
# PFTruth_overlay/PFTruth_overlay.second.charge_
# PFTruth_overlay/PFTruth_overlay.second.daughters_
# PFTruth_overlay/PFTruth_overlay.second.parents_
# PFTruth_overlay/PFTruth_overlay.second.process_type_
# PFTruth_overlay/PFTruth_overlay.second.vertex_volume_
# PFTruth_overlay/PFTruth_overlay.second.interaction_material_
# PFTruthTarget_overlay
# PFTruthTarget_overlay/PFTruthTarget_overlay.id_
# PFTruthTarget_overlay/PFTruthTarget_overlay.layer_id_
# PFTruthTarget_overlay/PFTruthTarget_overlay.module_id_
# PFTruthTarget_overlay/PFTruthTarget_overlay.edep_
# PFTruthTarget_overlay/PFTruthTarget_overlay.time_
# PFTruthTarget_overlay/PFTruthTarget_overlay.px_
# PFTruthTarget_overlay/PFTruthTarget_overlay.py_
# PFTruthTarget_overlay/PFTruthTarget_overlay.pz_
# PFTruthTarget_overlay/PFTruthTarget_overlay.energy_
# PFTruthTarget_overlay/PFTruthTarget_overlay.x_
# PFTruthTarget_overlay/PFTruthTarget_overlay.y_
# PFTruthTarget_overlay/PFTruthTarget_overlay.z_
# PFTruthTarget_overlay/PFTruthTarget_overlay.path_length_
# PFTruthTarget_overlay/PFTruthTarget_overlay.track_id_
# PFTruthTarget_overlay/PFTruthTarget_overlay.pdg_id_
# PFTruthEcal_overlay
# PFTruthEcal_overlay/PFTruthEcal_overlay.id_
# PFTruthEcal_overlay/PFTruthEcal_overlay.layer_id_
# PFTruthEcal_overlay/PFTruthEcal_overlay.module_id_
# PFTruthEcal_overlay/PFTruthEcal_overlay.edep_
# PFTruthEcal_overlay/PFTruthEcal_overlay.time_
# PFTruthEcal_overlay/PFTruthEcal_overlay.px_
# PFTruthEcal_overlay/PFTruthEcal_overlay.py_
# PFTruthEcal_overlay/PFTruthEcal_overlay.pz_
# PFTruthEcal_overlay/PFTruthEcal_overlay.energy_
# PFTruthEcal_overlay/PFTruthEcal_overlay.x_
# PFTruthEcal_overlay/PFTruthEcal_overlay.y_
# PFTruthEcal_overlay/PFTruthEcal_overlay.z_
# PFTruthEcal_overlay/PFTruthEcal_overlay.path_length_
# PFTruthEcal_overlay/PFTruthEcal_overlay.track_id_
# PFTruthEcal_overlay/PFTruthEcal_overlay.pdg_id_
# PFTruthHcal_overlay
# PFTruthHcal_overlay/PFTruthHcal_overlay.id_
# PFTruthHcal_overlay/PFTruthHcal_overlay.layer_id_
# PFTruthHcal_overlay/PFTruthHcal_overlay.module_id_
# PFTruthHcal_overlay/PFTruthHcal_overlay.edep_
# PFTruthHcal_overlay/PFTruthHcal_overlay.time_
# PFTruthHcal_overlay/PFTruthHcal_overlay.px_
# PFTruthHcal_overlay/PFTruthHcal_overlay.py_
# PFTruthHcal_overlay/PFTruthHcal_overlay.pz_
# PFTruthHcal_overlay/PFTruthHcal_overlay.energy_
# PFTruthHcal_overlay/PFTruthHcal_overlay.x_
# PFTruthHcal_overlay/PFTruthHcal_overlay.y_
# PFTruthHcal_overlay/PFTruthHcal_overlay.z_
# PFTruthHcal_overlay/PFTruthHcal_overlay.path_length_
# PFTruthHcal_overlay/PFTruthHcal_overlay.track_id_
# PFTruthHcal_overlay/PFTruthHcal_overlay.pdg_id_
# PFHcalClusters_overlay
# PFHcalClusters_overlay/PFHcalClusters_overlay.hit_ids_
# PFHcalClusters_overlay/PFHcalClusters_overlay.energy_
# PFHcalClusters_overlay/PFHcalClusters_overlay.n_hits_
# PFHcalClusters_overlay/PFHcalClusters_overlay.centroid_x_
# PFHcalClusters_overlay/PFHcalClusters_overlay.centroid_y_
# PFHcalClusters_overlay/PFHcalClusters_overlay.centroid_z_
# PFHcalClusters_overlay/PFHcalClusters_overlay.layer_
# PFHcalClusters_overlay/PFHcalClusters_overlay.rms_x_
# PFHcalClusters_overlay/PFHcalClusters_overlay.rms_y_
# PFHcalClusters_overlay/PFHcalClusters_overlay.rms_z_
# PFHcalClusters_overlay/PFHcalClusters_overlay.dxdz_
# PFHcalClusters_overlay/PFHcalClusters_overlay.dydz_
# PFHcalClusters_overlay/PFHcalClusters_overlay.err_dxdz_
# PFHcalClusters_overlay/PFHcalClusters_overlay.err_dydz_
# PFHcalClusters_overlay/PFHcalClusters_overlay.hit_x_
# PFHcalClusters_overlay/PFHcalClusters_overlay.hit_y_
# PFHcalClusters_overlay/PFHcalClusters_overlay.hit_z_
# PFHcalClusters_overlay/PFHcalClusters_overlay.hit_e_
# HcalTotalEnergy_overlay
# EcalClustersCast_overlay
# EcalClustersCast_overlay/EcalClustersCast_overlay.hit_ids_
# EcalClustersCast_overlay/EcalClustersCast_overlay.energy_
# EcalClustersCast_overlay/EcalClustersCast_overlay.n_hits_
# EcalClustersCast_overlay/EcalClustersCast_overlay.centroid_x_
# EcalClustersCast_overlay/EcalClustersCast_overlay.centroid_y_
# EcalClustersCast_overlay/EcalClustersCast_overlay.centroid_z_
# EcalClustersCast_overlay/EcalClustersCast_overlay.layer_
# EcalClustersCast_overlay/EcalClustersCast_overlay.rms_x_
# EcalClustersCast_overlay/EcalClustersCast_overlay.rms_y_
# EcalClustersCast_overlay/EcalClustersCast_overlay.rms_z_
# EcalClustersCast_overlay/EcalClustersCast_overlay.dxdz_
# EcalClustersCast_overlay/EcalClustersCast_overlay.dydz_
# EcalClustersCast_overlay/EcalClustersCast_overlay.err_dxdz_
# EcalClustersCast_overlay/EcalClustersCast_overlay.err_dydz_
# EcalClustersCast_overlay/EcalClustersCast_overlay.hit_x_
# EcalClustersCast_overlay/EcalClustersCast_overlay.hit_y_
# EcalClustersCast_overlay/EcalClustersCast_overlay.hit_z_
# EcalClustersCast_overlay/EcalClustersCast_overlay.hit_e_
# PFCandidates_overlay
# PFCandidates_overlay/PFCandidates_overlay.pid_
# PFCandidates_overlay/PFCandidates_overlay.mass_
# PFCandidates_overlay/PFCandidates_overlay.energy_
# PFCandidates_overlay/PFCandidates_overlay.pos_targ_x_
# PFCandidates_overlay/PFCandidates_overlay.pos_targ_y_
# PFCandidates_overlay/PFCandidates_overlay.pos_targ_z_
# PFCandidates_overlay/PFCandidates_overlay.pos_ecal_x_
# PFCandidates_overlay/PFCandidates_overlay.pos_ecal_y_
# PFCandidates_overlay/PFCandidates_overlay.pos_ecal_z_
# PFCandidates_overlay/PFCandidates_overlay.pos_hcal_x_
# PFCandidates_overlay/PFCandidates_overlay.pos_hcal_y_
# PFCandidates_overlay/PFCandidates_overlay.pos_hcal_z_
# PFCandidates_overlay/PFCandidates_overlay.track_px_
# PFCandidates_overlay/PFCandidates_overlay.track_py_
# PFCandidates_overlay/PFCandidates_overlay.track_pz_
# PFCandidates_overlay/PFCandidates_overlay.ecal_energy_
# PFCandidates_overlay/PFCandidates_overlay.ecal_raw_energy_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_x_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_y_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_z_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_ex_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_ey_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_ez_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_dxdz_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_dydz_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_edxdz_
# PFCandidates_overlay/PFCandidates_overlay.ecal_cluster_edydz_
# PFCandidates_overlay/PFCandidates_overlay.hcal_energy_
# PFCandidates_overlay/PFCandidates_overlay.hcal_raw_energy_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_x_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_y_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_z_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_ex_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_ey_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_ez_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_dxdz_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_dydz_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_edxdz_
# PFCandidates_overlay/PFCandidates_overlay.hcal_cluster_edydz_
# PFCandidates_overlay/PFCandidates_overlay.truth_ecal_x_
# PFCandidates_overlay/PFCandidates_overlay.truth_ecal_y_
# PFCandidates_overlay/PFCandidates_overlay.truth_ecal_z_
# PFCandidates_overlay/PFCandidates_overlay.truth_px_
# PFCandidates_overlay/PFCandidates_overlay.truth_py_
# PFCandidates_overlay/PFCandidates_overlay.truth_pz_
# PFCandidates_overlay/PFCandidates_overlay.truth_mass_
# PFCandidates_overlay/PFCandidates_overlay.truth_energy_
# PFCandidates_overlay/PFCandidates_overlay.truth_pdg_id_
# PFCandidates_overlay/PFCandidates_overlay.track_idx_
# PFCandidates_overlay/PFCandidates_overlay.ecal_idx_
# PFCandidates_overlay/PFCandidates_overlay.hcal_idx_
# EcalRecHitsNoPileup_overlay
# EcalRecHitsNoPileup_overlay/EcalRecHitsNoPileup_overlay.id_
# EcalRecHitsNoPileup_overlay/EcalRecHitsNoPileup_overlay.amplitude_
# EcalRecHitsNoPileup_overlay/EcalRecHitsNoPileup_overlay.energy_
# EcalRecHitsNoPileup_overlay/EcalRecHitsNoPileup_overlay.time_
# EcalRecHitsNoPileup_overlay/EcalRecHitsNoPileup_overlay.xpos_
# EcalRecHitsNoPileup_overlay/EcalRecHitsNoPileup_overlay.ypos_
# EcalRecHitsNoPileup_overlay/EcalRecHitsNoPileup_overlay.zpos_
# EcalRecHitsNoPileup_overlay/EcalRecHitsNoPileup_overlay.is_noise_

# %% [markdown]
# Number of events, overlay tree true/false tag

# %%
num_events = tree.num_entries
print(f"\nNumber of events in the tree: {num_events}")

# Overlay tree tag
overlay_tree = any("overlay" in b for b in tree.keys())

if overlay_tree:
    print("\nThis is an overlay tree file")
else:
    print("\nThis is not an overlay tree file")
# Out:
# Number of events in the tree: 10
#
# This is an overlay tree file

# %% [markdown]
# ## Plots!
#
# Energy distribution, 2D plots, 3D plot
#
# Hitta EcalRecHits i x, y, z
#
# Hitta energierna för de olika hits som finns och plotta i histogram

# %%
# To array x, y ,z and energy of Ecal RecHits
if overlay_tree:
    # x,y,z and reconstructed energy of ECal 
    ecal_y = tree["EcalRecHits_overlay/EcalRecHits_overlay.ypos_"].array()
    ecal_x = tree["EcalRecHits_overlay/EcalRecHits_overlay.xpos_"].array()
    ecal_z = tree["EcalRecHits_overlay/EcalRecHits_overlay.zpos_"].array()
    ecal_energy = tree["EcalRecHits_overlay/EcalRecHits_overlay.energy_"].array()
else: # x,y,z and **deposited** energy in ECal
    ecal_y = tree["EcalSimHits_pileup/EcalSimHits_pileup.y_"].array()
    ecal_x = tree["EcalSimHits_pileup/EcalSimHits_pileup.x_"].array()
    ecal_z = tree["EcalSimHits_pileup/EcalSimHits_pileup.z_"].array()
    ecal_energy = tree["EcalSimHits_pileup/EcalSimHits_pileup.edep_"].array()
    # Energy of particle when crossing detector surfaces (truth kinematics)
    # TargetScoringPlaneHits_pileup/TargetScoringPlaneHits_pileup.energy_
    
    # SimHit deposited energies (truth detector response)
    # EcalSimHits_pileup/EcalSimHits_pileup.edep_

    # Particle (truth) energy
    # SimParticles_pileup/SimParticles_pileup.second.energy_

# Create figure
fig, ax = plt.subplots(1, 1, figsize=(16, 8))
ax.hist(ak.flatten(ecal_energy), bins=100, alpha=0.7, color='blue', range=[0,400])
if overlay_tree:
    ax.set_title("Ecal RecHit Energy Distribution")
else:
    ax.set_title("Ecal SimHit Energy Distribution")
ax.set_xlabel("Energy (MeV)")
ax.set_ylabel("Counts")
plt.savefig(f"{figures_path}ecal_energy.png", dpi=300)
#plt.close()

# %% [markdown]
# ### 2D: z vs x plot

# %%
# Scatter plots of x vs z for up to first 9 events (3x3 grid)

rows, columns = 3, 3
nplots = rows * columns
nevents = len(ecal_x)
nshow = min(nplots, nevents)

fig, ax = plt.subplots(rows, columns, figsize=(12, 12))
ax = ax.flatten()

for index in range(nshow):
    ax[index].scatter(ecal_x[index], ecal_z[index], s=4)
    ax[index].set_title(f"Event {index}")
    ax[index].set_xlabel("X Position [mm]")
    ax[index].set_ylabel("Z Position [mm]")
    ax[index].set_xlim(-300, 300)
    ax[index].set_ylim(200, 700)

# turn off unused panels if fewer than 9 events
for index in range(nshow, nplots):
    ax[index].axis("off")

plt.tight_layout()

plt.savefig(f"{figures_path}ecal_x_z_hits_3x3.png", dpi=300)
plt.show()

# %% [markdown]
# ### 2D: y vs z plot

# %%
# Scatter plots of y vs z for up to first 9 events (3x3 grid)

rows, columns = 3, 3
nplots = rows * columns
nevents = len(ecal_y)
nshow = min(nplots, nevents)

fig, ax = plt.subplots(rows, columns, figsize=(12, 12))
ax = ax.flatten()

for index in range(nshow):
    ax[index].scatter(ecal_y[index], ecal_z[index], s=4)
    ax[index].set_title(f"Event {index}")
    ax[index].set_xlabel("Y Position [mm]")
    ax[index].set_ylabel("Z Position [mm]")
    ax[index].set_xlim(-300, 300)
    ax[index].set_ylim(200, 700)

# turn off unused panels
for index in range(nshow, nplots):
    ax[index].axis("off")

plt.tight_layout()
plt.savefig(f"{figures_path}ecal_y_z_hits_3x3.png", dpi=300)
plt.show()

# %% [markdown]
# ### 3D plot

# %%
from mpl_toolkits.mplot3d import Axes3D  # needed for 3D projection
import awkward as ak
import matplotlib.pyplot as plt

event_idx = 0

# convert one event to regular numpy arrays
x = ak.to_numpy(ecal_x[event_idx])
y = ak.to_numpy(ecal_y[event_idx])
z = ak.to_numpy(ecal_z[event_idx])
e = ak.to_numpy(ecal_energy[event_idx])

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")

sc = ax.scatter(x, y, z, c=e, s=10, alpha=0.8)

ax.set_title(f"ECal RecHits in 3D, Event {event_idx}")
ax.set_xlabel("X Position [mm]")
ax.set_ylabel("Y Position [mm]")
ax.set_zlabel("Z Position [mm]")

ax.set_xlim(-300, 300)
ax.set_ylim(-300, 300)
ax.set_zlim(200, 700)

cbar = plt.colorbar(sc, ax=ax, pad=0.1)
cbar.set_label("Energy [MeV]")

plt.tight_layout()
plt.savefig(f"{figures_path}ecal_hits_3d_event0.png", dpi=300)
plt.show()

# %% [markdown]
# ### Interactive 3D

# %%
import plotly.graph_objects as go

event_idx = 0

x = ak.to_numpy(ecal_x[event_idx])
y = ak.to_numpy(ecal_y[event_idx])
z = ak.to_numpy(ecal_z[event_idx])
e = ak.to_numpy(ecal_energy[event_idx])

fig = go.Figure(
    data=[
        go.Scatter3d(
            x=x,
            y=y,
            z=z,
            mode="markers",
            marker=dict(
                size=3,
                color=e,
                colorscale="Viridis",
                colorbar=dict(title="Energy [MeV]"),
                opacity=0.8,
            ),
        )
    ]
)

fig.update_layout(
    title=f"ECal {('RecHits' if overlay_tree else 'SimHits')} 3D (Event {event_idx})",
    scene=dict(
        xaxis_title="X [mm]",
        yaxis_title="Y [mm]",
        zaxis_title="Z [mm]",
        xaxis=dict(range=[-300, 300]),
        yaxis=dict(range=[-300, 300]),
        zaxis=dict(range=[200, 700]),
    ),
    margin=dict(l=0, r=0, b=0, t=40),
)

fig.show()
